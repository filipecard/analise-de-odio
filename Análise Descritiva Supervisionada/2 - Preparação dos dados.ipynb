# %% [markdown]
# # Preparação dos dados

# %% [markdown]
# ## 1- Importação do dataset

# %%
import pandas as pd
pd.set_option('max_colwidth', 300)

# %%
data = pd.read_csv('./arquivos/data.csv', encoding='ISO-8859-1')

# %%
data.head(15)
# Out:
#                                                                                                                                                                                 tweet_text  \
# 0                                                                                                                                             Warning: penny boards will make you a faggot
# 1                                                                                                                                                                               Fuck dykes
# 2                                                                          @sizzurp__ @ILIKECATS74 @yoPapi_chulo @brandonernandez @bootyacid at least i dont look like jefree starr faggot
# 3                                                                                                        "@jayswaggkillah: "@JacklynAnnn: @jayswaggkillah Is a fag" jackie jealous" Neeeee
# 4                                                                                     @Zhugstubble You heard me bitch but any way I'm back th texas so wtf u talking about bitch ass nigga
# 5                                             @elaynay your a dirty terrorist and your religion is a fucking joke, you go around screaming Allah akbar doing terrorist shit. Dirty faggot.
# 6                                                                                                                                    RT @ivanrabago_: @_WhitePonyJr_ looking like faggots?
# 7   Well I thought you knew actually RT @KingHorseDick: Man why y'all didn't tell me I was a dick riding ass faggot? Y'all not real &#128557;&#128557;&#128557;&#128557;&#128557;&#128557;
# 8                                                                                                                                             @Stonisnipezz I know. It was a joke, faggot.
# 9                                                                           I'm tired of people saying I look like my brother &amp; calling me Deondre' like serious Succ My Ass fag asses
# 10                                                  #VoteBlue2014 Yeah. CUZ 8 million people in faggot ass #newyork are #chickenshit JEWS&gt; FUCK THEM right? Fuck Bibi Netanyahu. RIGHT?
# 11                                                                                                                       @AndreBerto word is you use roids, stupid hypocrite lying faggot.
# 12                                                                                                                                                                 I hate faggots like you
# 13                                                                                 @MoriTaheripour shut up nigger whore! Hope u get raped by one of those animals. Might change your tune.
# 14                                                                               @Oprah @3LWTV Fuck you nigger sheboon. Hope you r strung up like all niggers should be. WHITEPOWER. #1488
#
#     confidence labels  length
# 0       0.6013      O      44
# 1       0.7227      H      10
# 2       0.5229      H     111
# 3       0.5184      H      81
# 4       0.5185      O     100
# 5       0.8816      H     140
# 6       0.5207      H      53
# 7       0.5619      H     182
# 8       0.6419      O      44
# 9       0.6407      O     110
# 10      0.7619      H     134
# 11      0.5606      H      65
# 12      0.8435      H      23
# 13      0.8414      H     103
# 14      0.8826      H     105

# %% [markdown]
# ### 2- Limpeza do texto

# %%
import re
import string

# %% [markdown]
# >Criação das regexes

# %%
def clean_text_round1(text):
    text = text.lower()
    text = re.sub(r'@(\w+)\W', ' ', text) #Substituir menções de usuários
    text = re.sub(r'https?://\S*', ' ', text) #Remover links
    text = re.sub(r'&[^;.]*;', ' ', text) #Apagar elementos de html    
    text = re.sub('[%s]' % string.punctuation.replace("'",''), " ", text) # Remove pontuações
    text = re.sub(r'(.)\1{3,}', r'\1\1', text) # Ajusta repetições
    text = re.sub('\s{2,}', ' ', text) #Remover excesso de espaços
    text = re.sub(r'\s', ' ', text) #Remover whitespaces    
    return text

round1 = lambda x: clean_text_round1(x)

# %% [markdown]
# >Aplicação da limpeza

# %%
clean = data.drop(columns='tweet_text')
clean['tweet_text'] = pd.DataFrame.from_dict(data.tweet_text.apply(round1))
clean['length'] = [len(text) for text in clean.tweet_text]

# %% [markdown]
# ## 3- Visualização da limpeza

# %%
clean.head(15)
# Out:
#     confidence labels  length  \
# 0       0.6013      O      43
# 1       0.7227      H      10
# 2       0.5229      H      46
# 3       0.5184      H      28
# 4       0.5185      O      88
# 5       0.8816      H     130
# 6       0.5207      H      24
# 7       0.5619      H     111
# 8       0.6419      O      29
# 9       0.6407      O     104
# 10      0.7619      H     125
# 11      0.5606      H      53
# 12      0.8435      H      23
# 13      0.8414      H      86
# 14      0.8826      H      88
#
#                                                                                                                             tweet_text
# 0                                                                                          warning penny boards will make you a faggot
# 1                                                                                                                           fuck dykes
# 2                                                                                        at least i dont look like jefree starr faggot
# 3                                                                                                          is a fag jackie jealous nee
# 4                                              you heard me bitch but any way i'm back th texas so wtf u talking about bitch ass nigga
# 5    your a dirty terrorist and your religion is a fucking joke you go around screaming allah akbar doing terrorist shit dirty faggot
# 6                                                                                                             rt looking like faggots
# 7                      well i thought you knew actually rt man why y'all didn't tell me i was a dick riding ass faggot y'all not real
# 8                                                                                                         i know it was a joke faggot
# 9                             i'm tired of people saying i look like my brother calling me deondre' like serious succ my ass fag asses
# 10        voteblue2014 yeah cuz 8 million people in faggot ass newyork are chickenshit jews fuck them right fuck bibi netanyahu right
# 11                                                                                word is you use roids stupid hypocrite lying faggot
# 12                                                                                                             i hate faggots like you
# 13                                               shut up nigger whore hope u get raped by one of those animals might change your tune
# 14                                             fuck you nigger sheboon hope you r strung up like all niggers should be whitepower 1488

# %%
clean.describe()
# Out:
#          confidence        length
# count  14509.000000  14509.000000
# mean       0.865844     73.061134
# std        0.178734     35.850743
# min        0.333300      4.000000
# 25%        0.668400     43.000000
# 50%        1.000000     71.000000
# 75%        1.000000    103.000000
# max        1.000000    465.000000

# %% [markdown]
# # 4- Salvar arquivo

# %%
clean.to_csv('./arquivos/clean.csv', encoding='ISO-8859-1', index=False)
